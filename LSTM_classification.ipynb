# %%
import pandas as pd
import numpy as np

# %%
df  = pd.read_csv('/content/All_Gestures_Deceptive and Truthful.csv')

# %%
df.head()
# Out:
#                   id  OtherGestures  Smile  Laugh  Scowl  \
# 0  trial_lie_001.mp4              1      0      0      0
# 1  trial_lie_002.mp4              1      0      0      0
# 2  trial_lie_003.mp4              1      0      0      0
# 3  trial_lie_004.mp4              1      0      0      0
# 4  trial_lie_005.mp4              1      0      0      0
#
#    otherEyebrowMovement  Frown  Raise  OtherEyeMovements  Close-R  ...  \
# 0                     1      0      0                  1        0  ...
# 1                     0      1      0                  1        0  ...
# 2                     0      1      0                  0        1  ...
# 3                     1      0      0                  1        0  ...
# 4                     0      1      0                  1        0  ...
#
#    forwardHead  downRHead  singleHand  bothHands  otherHandM  complexHandM  \
# 0            0          0           0          0           1             0
# ...

# %%
df.shape
# Out:
# (121, 41)

# %%
df.describe()
# Out:
#        OtherGestures       Smile       Laugh       Scowl  \
# count     121.000000  121.000000  121.000000  121.000000
# mean        0.652893    0.123967    0.008264    0.214876
# std         0.478030    0.330914    0.090909    0.412444
# min         0.000000    0.000000    0.000000    0.000000
# 25%         0.000000    0.000000    0.000000    0.000000
# 50%         1.000000    0.000000    0.000000    0.000000
# 75%         1.000000    0.000000    0.000000    0.000000
# max         1.000000    1.000000    1.000000    1.000000
#
#        otherEyebrowMovement       Frown       Raise  OtherEyeMovements  \
# count            121.000000  121.000000  121.000000         121.000000
# mean               0.289256    0.206612    0.504132           0.454545
# std                0.455302    0.406558    0.502062           0.500000
# min                0.000000    0.000000    0.000000           0.000000
# 25%                0.000000    0.000000    0.000000           0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121 entries, 0 to 120
# Data columns (total 41 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    121 non-null    object
#  1   OtherGestures         121 non-null    int64
#  2   Smile                 121 non-null    int64
#  3   Laugh                 121 non-null    int64
#  4   Scowl                 121 non-null    int64
#  5   otherEyebrowMovement  121 non-null    int64
#  6   Frown                 121 non-null    int64
#  7   Raise                 121 non-null    int64
#  8   OtherEyeMovements     121 non-null    int64
#  9   Close-R               121 non-null    int64
#  10  X-Open                121 non-null    int64
#  11  Close-BE              121 non-null    int64
#  12  gazeInterlocutor      121 non-null    int64
#  13  gazeDown              121 non-null    int64
#  14  gazeUp                121 non-null    int64
# ...

# %%
df['class'].unique()
# Out:
# array(['deceptive', 'truthful'], dtype=object)

# %%
#Convert Target Feature to Numeric i.e . truthful:1,deceptive:0

# %%
df['class'].replace(['deceptive', 'truthful'],
                        [0, 1], inplace=True)

# %%
df['class']
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 116    1
# 117    1
# 118    1
# 119    1
# 120    1
# Name: class, Length: 121, dtype: int64
