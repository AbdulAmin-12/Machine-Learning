# %%
# getting an image using web get

# !wget 'https://tractive.com/blog/wp-content/uploads/2016/04/puppy-care-guide-for-new-parents.jpg'
# Out:
# --2022-06-19 09:59:41--  https://tractive.com/blog/wp-content/uploads/2016/04/puppy-care-guide-for-new-parents.jpg
# Resolving tractive.com (tractive.com)... 18.67.0.100, 18.67.0.76, 18.67.0.124, ...
# Connecting to tractive.com (tractive.com)|18.67.0.100|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 113570 (111K) [image/jpeg]
# Saving to: ‘puppy-care-guide-for-new-parents.jpg.2’
#
# puppy-care-guide-fo 100%[===================>] 110.91K  --.-KB/s    in 0.04s
#
# 2022-06-19 09:59:41 (2.81 MB/s) - ‘puppy-care-guide-for-new-parents.jpg.2’ saved [113570/113570]

# %% [markdown]
# # New Section

# %% [markdown]
# # New Section
