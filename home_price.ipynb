# %%
import pandas as pd
df = pd.read_csv('‪/content/amin.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-eb1decb1afe6> in <module>
#       1 import pandas as pd
# ----> 2 df = pd.read_csv('‪/content/amin.csv')
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
import pandas as pd
df= pd.read_csv('/content/amin.csv')

# %%
df.head()
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484
# 3  1973              4804.463248
# 4  1974              5576.514583

# %%
df.describe()
# Out:
#               year  per capita income (US$)
# count    47.000000                47.000000
# mean   1993.000000             18920.137063
# std      13.711309             12034.679438
# min    1970.000000              3399.299037
# 25%    1981.500000              9526.914515
# 50%    1993.000000             16426.725480
# 75%    2004.500000             27458.601420
# max    2016.000000             42676.468370

# %%
df['per capita income (US$)'] = df['per capita income (US$)'].astype(int)

# %%
a = df['year']
b= ['per capita income (US$)']
c = b.astype(int)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-fbb04eb6da84> in <module>
#       1 a = df['year']
#       2 b= ['per capita income (US$)']
# ----> 3 c = b.astype(int)
#
# AttributeError: 'list' object has no attribute 'astype'

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.xlabel('year')
plt.ylabel('income')
plt.scatter(a,df['per capita income (US$)'],color='red',marker='+')

# %%
new_df = df.drop('per capita income (US$)',axis='columns')
new_df
# Out:
#     year
# 0   1970
# 1   1971
# 2   1972
# 3   1973
# 4   1974
# 5   1975
# 6   1976
# 7   1977
# 8   1978
# 9   1979
# 10  1980
# 11  1981
# 12  1982
# 13  1983
# 14  1984
# 15  1985
# 16  1986
# 17  1987
# 18  1988
# 19  1989
# 20  1990
# 21  1991
# 22  1992
# 23  1993
# 24  1994
# 25  1995
# 26  1996
# 27  1997
# 28  1998
# 29  1999
# 30  2000
# 31  2001
# 32  2002
# 33  2003
# 34  2004
# 35  2005
# 36  2006
# 37  2007
# 38  2008
# 39  2009
# 40  2010
# 41  2011
# 42  2012
# 43  2013
# 44  2014
# 45  2015
# 46  2016

# %%
price = df['per capita income (US$)']
price
# Out:
# 0      3399
# 1      3768
# 2      4251
# 3      4804
# 4      5576
# 5      5998
# 6      7062
# 7      7100
# 8      7247
# 9      7602
# 10     8355
# 11     9434
# 12     9619
# 13    10416
# 14    10790
# 15    11018
# 16    11482
# 17    12974
# 18    15080
# 19    16426
# 20    16838
# 21    17266
# 22    16412
# 23    15875
# 24    15755
# 25    16369
# 26    16699
# 27    17310
# 28    16622
# 29    17581
# 30    18987
# 31    18601
# 32    19232
# 33    22739
# 34    25719
# 35    29198
# 36    32738
# 37    36144
# 38    37446
# 39    32755
# 40    38420
# 41    42334
# 42    42665
# 43    42676
# 44    41039
# 45    35175
# 46    34229
# Name: per capita income (US$), dtype: int64

# %%
# Create linear regression object
from sklearn import linear_model
import matplotlib.pyplot as plt
reg = linear_model.LinearRegression()
reg.fit(new_df,price)
# Out:
# LinearRegression()

# %%
reg.predict([[2020]])
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   "X does not have valid feature names, but"
# array([41288.29417206])

# %%
import pandas as pd

# %%
df = pd.read_csv('/cardata.csv')

# %%
df
# Out:
#                 Car Model  Mileage  Sell Price($)  Age(yrs)
# 0                  BMW X5    69000          18000         6
# 1                  BMW X5    35000          34000         3
# 2                  BMW X5    57000          26100         5
# 3                  BMW X5    22500          40000         2
# 4                  BMW X5    46000          31500         4
# 5                 Audi A5    59000          29400         5
# 6                 Audi A5    52000          32000         5
# 7                 Audi A5    72000          19300         6
# 8                 Audi A5    91000          12000         8
# 9   Mercedez Benz C class    67000          22000         6
# 10  Mercedez Benz C class    83000          20000         7
# 11  Mercedez Benz C class    79000          21000         7
# 12  Mercedez Benz C class    59000          33000         5
